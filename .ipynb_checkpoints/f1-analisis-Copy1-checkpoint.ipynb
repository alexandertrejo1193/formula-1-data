# %% [markdown]
# ### Sprint results

# %%
sprintResult={"year":[],"raceId":[],"driverId":[],"round":[],"constructorId":[],"number":[],
             "grid":[],"position":[],"positionText":[],"points":[],"laps":[],"time":[],
             "miliseconds":[],"fastestLap":[],"statusId":[],"fastestLapTime":[]}
for year in range(year1,year2):
    url='http://ergast.com/api/f1' 
    url1=url+'/{}.json?limit=1000'
    url3=url+'/{}'.format(year)
    response = requests.get(url1.format(year))
    content=json.loads(response.content)
    urls=[]
    for i in range(1,len(content['MRData']['RaceTable']['Races'])+1):
        url2=url3+'/{}/sprint.json?limit=1000'
        response = requests.get(url2.format(i))
        content=json.loads(response.content)
        urls.append(url2.format(i))
    i=0 
    for j in urls:
        response = requests.get(j)
        content=json.loads(response.content)
        
        try:
            for item in content['MRData']['RaceTable']['Races'][0]['SprintResults']:
                sprintResult["year"].append(int(content['MRData']['RaceTable']['Races'][0]['season']))
                sprintResult["driverId"].append(item["Driver"]["driverId"])
                sprintResult["raceId"].append(content['MRData']['RaceTable']['Races'][0]['raceName'])
                sprintResult["round"].append(int(content['MRData']['RaceTable']['Races'][0]['round']))
                sprintResult["constructorId"].append(item["Constructor"]["constructorId"])
                sprintResult["number"].append(int(item['Driver']['permanentNumber']))
                sprintResult["grid"].append(int(item["grid"]))
                sprintResult["position"].append(int(item['position']))
                sprintResult["positionText"].append(item['positionText'])
                sprintResult["points"].append(int(item['points']))
                sprintResult["laps"].append(int(item['laps']))
                try:
                    sprintResult["time"].append(item["Time"]["time"])
                except:
                    sprintResult["time"].append(0)
                try:
                    sprintResult["miliseconds"].append(item["Time"]["millis"])
                except:
                    sprintResult["miliseconds"].append("")
                try:    
                    sprintResult["fastestLap"].append(item['FastestLap']["lap"])
                except:
                    sprintResult["fastestLap"].append("")
                try:    
                    sprintResult["fastestLapTime"].append(item['FastestLap']['Time']['time'])
                except:
                    sprintResult["fastestLapTime"].append("")
                try:    
                    sprintResult["statusId"].append(item['status'])
                except:
                    sprintResult["statusId"].append("")
        except:
            asd=1
                
                
sprintResultt=pd.DataFrame.from_dict(sprintResult,orient='index')
sprintResultt=sprintResultt.transpose()
sprintResultt.head()
sprintResultt.to_csv('SprintResult.csv')
# Out:
# Hay un error en http://ergast.com/api/f1/2010/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2011/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2012/20/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2013/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2014/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2015/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/20/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2016/21/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2017/20/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/20/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2018/21/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/20/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2019/21/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2020/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/4/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/11/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/20/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/21/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/22/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/1/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/2/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/3/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/5/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/6/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/7/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/8/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/9/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/10/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/12/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/13/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/14/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/15/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/16/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/17/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/18/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/19/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/20/sprint.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2022/22/sprint.json?limit=1000
#    year              raceId        driverId round constructorId number grid  \
# 0  2021  British Grand Prix  max_verstappen    10      red_bull     33    2
# 1  2021  British Grand Prix        hamilton    10      mercedes     44    1
# 2  2021  British Grand Prix          bottas    10      mercedes     77    3
# 3  2021  British Grand Prix         leclerc    10       ferrari     16    4
# 4  2021  British Grand Prix          norris    10       mclaren      4    6
#
#   position positionText points laps       time miliseconds fastestLap  \
# 0        1            1      3   17  25:38.426     1538426         14
# 1        2            2      2   17     +1.430     1539856         17
# 2        3            3      1   17     +7.502     1545928         17
# 3        4            4      0   17    +11.278     1549704         16
# 4        5            5      0   17    +24.111     1562537         16
#
#    statusId fastestLapTime
# 0  Finished       1:30.013
# 1  Finished       1:29.937
# 2  Finished       1:29.958
# 3  Finished       1:30.163
# 4  Finished       1:30.566

# %% [markdown]
# ### Status

# %%
warnings.filterwarnings("ignore")
status={"year":[],"statusId":[],"status":[]}
for year in range(year1,year2):
    url='http://ergast.com/api/f1/{}/status.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in content['MRData']['StatusTable']["Status"]:
        status["statusId"].append(item['statusId'])
        status["status"].append(item['status'])
        status["year"].append(content['MRData']['StatusTable']['season'])

statuss=pd.DataFrame(status)
statuss.head()
statuss.to_csv('status.csv')
# Out:
#    year statusId     status
# 0  2010        1   Finished
# 1  2010        3   Accident
# 2  2010        4  Collision
# 3  2010        5     Engine
# 4  2010        6    Gearbox

# %% [markdown]
# ### Results

# %%
results2={"year":[],"raceId":[],"driverId":[],"constructorId":[],"number":[],
             "grid":[],"position":[],"positionText":[],"points":[],"laps":[],"time":[],
             "miliseconds":[],"fastestLap":[],"fastestLapSpeed":[],"statusId":[],"fastestLapTime":[],"round":[]}#,"ResultId":[],"positionOrder":[]}
for year in range(year1,year2):
    url='http://ergast.com/api/f1' 
    url1=url+'/{}.json?limit=1000'
    url3=url+'/{}'.format(year)
    response = requests.get(url1.format(year))
    content=json.loads(response.content)
    tampath=len(content['MRData']['RaceTable']['Races'])
    links=[]
    for i in range(1,tampath+1):
        url2=url3+'/{}/results.json?limit=1000'
        response = requests.get(url2.format(i))
        content=json.loads(response.content)
        links.append(url2.format(i))
    i=0 
    for j in links:
        response = requests.get(j)
        content=json.loads(response.content)
        
        for item in content['MRData']['RaceTable']['Races'][0]['Results']:
            #results2["ResultId"].append()
            results2["year"].append(int(content['MRData']['RaceTable']['Races'][0]['season']))
            results2["raceId"].append(content['MRData']['RaceTable']['Races'][0]['raceName'])
            results2["round"].append(int(content['MRData']['RaceTable']['Races'][0]['round']))
            results2["driverId"].append(item['Driver']['driverId'])
            results2["constructorId"].append(item['Constructor']['constructorId'])
            try:
                results2["number"].append(item['Driver']['permanentNumber'])
            except:
                results2["number"].append("")
            results2["grid"].append(item['grid'])
            results2["position"].append(int(item['position']))
            results2["positionText"].append(item['positionText'])
            #results2["positionOrder"].append()
            results2["points"].append(float(item['points']))
            results2["laps"].append(int(item['laps']))
            try:
                results2["time"].append(item['Time']['time'])
            except:
                results2["time"].append("")
            try:
                results2["miliseconds"].append(int(item['Time']['millis']))
            except: 
                results2["miliseconds"].append("")
            try:
                results2["fastestLap"].append(int(item['FastestLap']['lap']))
            except: 
                results2["fastestLap"].append("")
            try:
                results2["fastestLapTime"].append(item['FastestLap']['Time']['time'])
            except: 
                results2["fastestLapTime"].append("")
            try:
                results2["fastestLapSpeed"].append(item['FastestLap']['AverageSpeed']['speed'])
            except: 
                results2["fastestLapSpeed"].append("")
                
            try:
                results2["statusId"].append(item['status'])
            except: 
                results2["statusId"].append("")
                
            
resultss2=pd.DataFrame.from_dict(results2,orient='index')
resultss2=resultss2.transpose()           
resultss2.head()
resultss2.to_csv('Results.csv')
# Out:
#    year              raceId  driverId constructorId number grid position  \
# 0  2010  Bahrain Grand Prix    alonso       ferrari     14    3        1
# 1  2010  Bahrain Grand Prix     massa       ferrari     19    2        2
# 2  2010  Bahrain Grand Prix  hamilton       mclaren     44    4        3
# 3  2010  Bahrain Grand Prix    vettel      red_bull      5    1        4
# 4  2010  Bahrain Grand Prix   rosberg      mercedes      6    5        5
#
#   positionText points laps         time miliseconds fastestLap  \
# 0            1   25.0   49  1:39:20.396     5960396         45
# 1            2   18.0   49      +16.099     5976495         38
# 2            3   15.0   49      +23.182     5983578         42
# 3            4   12.0   49      +38.799     5999195         32
# 4            5   10.0   49      +40.213     6000609         45
#
#   fastestLapSpeed  statusId fastestLapTime round
# 0         191.706  Finished       1:58.287     1
# 1         189.392  Finished       1:59.732     1
# 2         189.665  Finished       1:59.560     1
# 3         188.627  Finished       2:00.218     1
# 4         188.599  Finished       2:00.236     1

# %% [markdown]
# ### PitStops

# %%
pitStops = {'year':[],"raceId":[],'driverId':[], 'stop':[],
           'lap':[], 'time':[],'round':[], 'duration':[]}#, 'milliseconds':[]}

for year in range(year1,year2):
    url='http://ergast.com/api/f1' 
    url1=url+'/{}.json?limit=1000'
    url3=url+'/{}'.format(year)
    response = requests.get(url1.format(year))
    content=json.loads(response.content)
    tampath=len(content['MRData']['RaceTable']['Races'])
    links=[]
    for i in range(1,tampath+1):
        url2=url3+'/{}/pitstops.json?limit=1000'
        response = requests.get(url2.format(i))
        content=json.loads(response.content)
        links.append(url2.format(i))
    i=0 
    for j in links:
        try:
            response = requests.get(j)
            content=json.loads(response.content)
        except:
            print(f"Hay un error en {j}")
        try: 
            content['MRData']['RaceTable']['Races'][0]['PitStops']
            for item in content['MRData']['RaceTable']['Races'][0]['PitStops']:
                pitStops["raceId"].append(content['MRData']['RaceTable']['Races'][0]['raceName'])
                pitStops["round"].append(int(content['MRData']['RaceTable']['Races'][0]['round']))
                pitStops["year"].append(int(content['MRData']['RaceTable']['Races'][0]['season']))
                pitStops["driverId"].append(item['driverId'])
                pitStops["stop"].append(int(item['stop']))
                pitStops["lap"].append(int(item['lap']))
                pitStops["time"].append(item['time'])
                pitStops["duration"].append(item['duration'])
            
        except:
            asd=1
            
        

pitStopss=pd.DataFrame(pitStops)         
pitStopss.head()  
pitStopss.to_csv('pitStops.csv')
# Out:
# Hay un error en http://ergast.com/api/f1/2010/1/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/2/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/3/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/4/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/5/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/6/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/7/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/8/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/9/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/10/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/11/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/12/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/13/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/14/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/15/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/16/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/17/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/18/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2010/19/pitstops.json?limit=1000
# Hay un error en http://ergast.com/api/f1/2021/12/pitstops.json?limit=1000
#    year                 raceId            driverId  stop  lap      time  \
# 0  2011  Australian Grand Prix         alguersuari     1    1  17:05:23
# 1  2011  Australian Grand Prix  michael_schumacher     1    1  17:05:52
# 2  2011  Australian Grand Prix              webber     1   11  17:20:48
# 3  2011  Australian Grand Prix              alonso     1   12  17:22:34
# 4  2011  Australian Grand Prix               massa     1   13  17:24:10
#
#    round duration
# 0      1   26.898
# 1      1   25.021
# 2      1   23.426
# 3      1   23.251
# 4      1   23.842
